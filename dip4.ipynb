# %%
pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\richa\anaconda3\envs\imageproc\lib\site-packages (4.7.0.72)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\richa\anaconda3\envs\imageproc\lib\site-packages (from opencv-python) (1.23.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\richa\anaconda3\envs\imageproc\lib\site-packages (3.7.1)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\richa\anaconda3\envs\imageproc\lib\site-packages (from matplotlib) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in c:\users\richa\anaconda3\envs\imageproc\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\richa\anaconda3\envs\imageproc\lib\site-packages (from matplotlib) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\richa\anaconda3\envs\imageproc\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in c:\users\richa\anaconda3\envs\imageproc\lib\site-packages (from matplotlib) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\richa\anaconda3\envs\imageproc\lib\site-packages (from matplotlib) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\richa\anaconda3\envs\imageproc\lib\site-packages (from matplotlib) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\richa\anaconda3\envs\imageproc\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\richa\anaconda3\envs\imageproc\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\richa\anaconda3\envs\imageproc\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import cv2
import matplotlib.pyplot as plt
gray_image = cv2.imread("gray.jpg")
clr_image = cv2.imread("color.jpg",-1)
cv2.imshow("Gray Image",gray_image)
cv2.imshow("Color Image",clr_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
import matplotlib.pyplot as plt
gray_image = cv2.imread("gray.jpg")
clr_image = cv2.imread("color.jpg",-1)
gray_hist = cv2.calcHist([gray_image],[0],None,[256],[0,256])
clr_hist = cv2.calcHist([clr_image],[0],None,[256],[0,256])
plt.figure()
plt.imshow(gray_image)
plt.show()
plt.title("Histogram")
plt.xlabel("Grayscale Value")
plt.ylabel("Pixel Count")
plt.stem(gray_hist)
plt.show()
plt.imshow(clr_image)
plt.show()
plt.title("Histogram of Color Image - Green Channel")
plt.xlabel("Intensity Value")
plt.ylabel("Pixel Count")
plt.stem(clr_hist)
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt
gray_image = cv2.imread("gray.jpg",0)
cv2.imshow("Gray Image",gray_image)
equ = cv2.equalizeHist(gray_image)
cv2.imshow("Equalized Image",equ)
cv2.waitKey(0)
cv2.destroyAllWindows()
